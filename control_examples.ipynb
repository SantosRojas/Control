# %% [markdown]
# # Ejemplos de uso del modulo control

# %%
#importamos la libreria, la cual deberia estar en la misma carpeta de trabajo o en todo caso agregarla al path
import control as cn
# %matplotlib notebook

# %%
#Declaramos las funciones de transferencia
sys_a=cn.tf(1,[0.5,1],0.5)
sys_b=cn.tf(2,[0.2,2])

# %%
#Serie de dos tf
sys_serie=cn.serie(sys_a,sys_b)
sys_serie
# Out:
# TransferFunctionContinuous(
# array([  20., -240.,  960.]),
# array([  1.,  24., 212., 816., 960.]),
# dt: None
# )

# %%
#Feedback
sys_f=cn.tf(2,1)
sys_feedback=cn.feedback(sys_a,sys_f)
sys_feedback
# Out:
# TransferFunctionContinuous(
# array([  2., -24.,  96.]),
# array([  1.,  18.,  24., 288.]),
# dt: None
# )

# %%
#Ploteo simple
cn.plot_step([sys_a,{'label':'Mi funcion 1'}],[sys_b,{'label':'Mi funcion 2'}],sys_feedback)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Ploteo modificando propiedades de cada sistema
cn.plot_step([sys_a,{'c':'m--','lw':2,'label':'Respuesta del orno'}],[sys_b,{'c':'c:','lw':3,'label':'Mi funcion 2'}],T=[0,3.5,100])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Ploteo con parametros
sys1=cn.tf(2,[1,0.8,2],0.5)#tf de segundo orden con retardo de 0.5 segundos
cn.plot_step(sys_a,sys1,params='all',legend_params=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Mostrando solo los parametros
cn.plot_step(sys_a,sys_b,sys_feedback,sys_serie,only_params=True,params='all')
# Out:
# =========== Parametros de Resp_tem_1 ===============
# Tiempo pico(S) = 3.5
# Tiempo de establecimiento(S) = 2.475
# Tiempo de levantamiento = 1.131
# Maximo sobreimpulso = 0.002
# Valor pico = 0.998
# Valor estable =  1.0
# =========== Parametros de Resp_tem_2 ===============
# Tiempo pico(S) = 0.7
# Tiempo de establecimiento(S) = 0.396
# Tiempo de levantamiento = 0.219
# Maximo sobreimpulso = 0.001
# Valor pico = 0.999
# Valor estable =  1.0
# =========== Parametros de Resp_tem_3 ===============
# Tiempo pico(S) = 0.98
# Tiempo de establecimiento(S) = 18.618
# Tiempo de levantamiento = 0.326
# Maximo sobreimpulso = 0.919
# Valor pico = 0.64
# Valor estable =  0.333
# =========== Parametros de Resp_tem_4 ===============
# Tiempo pico(S) = 3.5
# Tiempo de establecimiento(S) = 2.581
# Tiempo de levantamiento = 1.166
# Maximo sobreimpulso = 0.003
# Valor pico = 0.997
# Valor estable =  1.0

# %%
#ploteo de varios sistemas definiendo el vector de tiempo T
cn.plot_step(sys_a,sys_b,sys_feedback,sys_serie,
             T=[0,5,100],
             title='Mi grafica',
             xlabel='x(s)',
             ylabel='Y(T)')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Customizando el titulos y los axeslabel
cn.plot_step(sys1,sys_feedback,sys_serie,
             )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 #Customizando el titulos y los axeslabel
# ----> 2 cn.plot_step(sys1,sys_serie,
#       3              title='Mi grafica',
#       4              xlabel='x(s)',
#       5              ylabel='Y(T)',
#       6              T=[0,16,100])
#
# NameError: name 'sys1' is not defined
