# %% [markdown]
# # Ejemplos de uso del modulo control

# %%
#importamos la libreria, la cual deberia estar en la misma carpeta de trabajo o en todo caso agregarla al path
import control as cn
# %matplotlib notebook

# %%
#Declaramos las funciones de transferencia
sys_a=cn.tf(1,[0.5,1],0.5)
sys_b=cn.tf(2,[0.2,2])

# %%
#Serie de dos tf
sys_serie=cn.serie(sys_a,sys_b)
sys_serie
# Out:
# TransferFunctionContinuous(
# array([  20., -240.,  960.]),
# array([  1.,  24., 212., 816., 960.]),
# dt: None
# )

# %%
#Feedback
sys_f=cn.tf(2,1)
sys_feedback=cn.feedback(sys_a,sys_f)
sys_feedback
# Out:
# TransferFunctionContinuous(
# array([  2., -24.,  96.]),
# array([  1.,  18.,  24., 288.]),
# dt: None
# )

# %%
#Ploteo simple
cn.plot_step([sys_a,{'label':'Mi funcion 1'}],[sys_b,{'label':'Mi funcion 2'}],sys_feedback)
# Out:
# <div id='22c1c4e8-0168-496e-b949-1ddb5d12c090'></div>

# %%
#Ploteo modificando propiedades de cada sistema
cn.plot_step([sys_a,{'c':'m--','lw':2,'label':'Respuesta del orno'}],[sys_b,{'c':'c:','lw':3,'label':'Mi funcion 2'}],T=[0,3.5,100])
# Out:
# <div id='35947a8a-3561-4192-92ab-f1d8c3df97ed'></div>

# %%
#Ploteo con parametros
sys1=cn.tf(2,[1,0.8,2],0.5)#tf de segundo orden con retardo de 0.5 segundos
cn.plot_step(sys_a,sys1,params='all',legend_params=True)
# Out:
# <div id='516e425c-6c90-40a7-896e-cc7ded373389'></div>

# %%
#Mostrando solo los parametros
cn.plot_step(sys_a,sys_b,sys_feedback,sys_serie,params='all')
# Out:
# <div id='0d6dd196-a930-430b-bbe1-c320783b2c44'></div>

# %%
#ploteo de varios sistemas definiendo el vector de tiempo T
cn.plot_step(sys_a,sys_b,sys_feedback,sys_serie,
             T=[0,5,100],
             title='Mi grafica',
             xlabel='x(s)',
             ylabel='Y(T)')
# Out:
# <div id='7690e55d-75ca-4513-9379-db8370758da3'></div>

# %%
from control import *
import numpy as np

# %%
sys=tf(1,[0.6,1])

# %%
plot_step(sys,params='ts',anotation=True)

# %%
G=PI(sys,0.2,2)
plot_step([sys,{'label':'Sistema original','lw':3}],[G,{'label':'PID'}],params='vs,tp,ts,mp,vp',anotation=True,loc='center')

# %%
from control import *
import matplotlib.pyplot as plt

# %%
sys=tf([1,2],[1,0.8,3])
LGR(sys,xlim=[-20,20],ylim=[-3,3],fc='g',grid=True,anotation=True)
